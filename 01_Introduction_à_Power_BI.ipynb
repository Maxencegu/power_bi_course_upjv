# %% [markdown]
# <a href="https://colab.research.google.com/github/Maxencegu/power_bi_course_upjv/blob/main/01_Introduction_%C3%A0_Power_BI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Premiers pas avec Power BI**

# %% [markdown]
# Découvrez comment utiliser cet outil intuitif et familiarisez-vous avec les vues Data, Model et Report de Power BI.
#
# Vous chargerez plusieurs ensembles de données dans la vue Données, construirez un modèle de données pour comprendre les relations entre vos tables dans la vue Modèle, et créerez votre premier histogramme à barres et votre première visualisation de carte interactive dans la vue Rapport.
#
# Vous vous entraînerez également à utiliser Power Query Editor pour préparer vos données à l'analyse.

# %% [markdown]
# ## **1.1 Introduction à Power BI**

# %%
# @title
from IPython.display import HTML

pdf_url_01 = "https://raw.githubusercontent.com/Maxencegu/power_bi_course_upjv/main/introduction/presentations/presentation_01.pdf"

HTML(f"""
<a href="{pdf_url_01}" target="_blank" style="text-decoration:none;">
  <button style="
    font-size:16px;
    padding:10px 16px;
    cursor:pointer;
  ">
    📘 Ouvrir la présentation du cours (PDF)
  </button>
</a>
""")
# Out:
# <a href="https://raw.githubusercontent.com/Maxencegu/power_bi_course_upjv/main/introduction/presentations/presentation_01.pdf" target="_blank" style="text-decoration:none;">
#   <button style="
#     font-size:16px;
#     padding:10px 16px;
#     cursor:pointer;
#   ">
#     📘 Ouvrir la présentation du cours (PDF)
#   </button>
# </a>

# %%
# @title
from IPython.display import Image

# URL RAW du PNG sur GitHub
image_url_01 = "https://raw.githubusercontent.com/Maxencegu/power_bi_course_upjv/main/introduction/images/infographie_01.png"

# Affiche l'image
Image(url=image_url_01, width=800)
# Out:
# <img src="https://raw.githubusercontent.com/Maxencegu/power_bi_course_upjv/main/introduction/images/infographie_01.png" width="800"/>
